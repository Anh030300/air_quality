# %% [markdown]
# # Crawl with API

# %%
https://api.weather.com/v1/location/VVNB:9:VN/observations/historical.json?apiKey=e1f10a1e78da46f5b10a1e78da96f525&units=m&startDate=20210219
APIKey = "e1f10a1e78da46f5b10a1e78da96f525"

# %%
# %%writefile DateTimeHandlerInterface.py
class DateTimeHandlerInterface:
    def convert_timestampe(self, timestamp)->str:
        pass

    def get_num_days_of_year(self,year)->int:
        pass

    def get_date_from_day_num(self,year,day_num,str_format)->str:
        pass
# Out:
# Overwriting DateTimeHandlerInterface.py

# %%
# %%writefile VietNamDateTimeHandler.py
from DateTimeHandlerInterface import DateTimeHandlerInterface
import datetime
from datetime import timezone, timedelta
class VietNamDateTimeHandler(DateTimeHandlerInterface):
    def convert_timestampe(self, timestamp)->str:
        return datetime.datetime.fromtimestamp(timestamp,tz=timezone(timedelta(hours=7))).strftime("%Y-%m-%d %H:%M:%S")

    def get_num_days_of_year(self,year)->int:
        return ((datetime.date(year,12,31)-datetime.date(year,1,1)).days+1)

    def get_date_from_day_num(self,year,day_num,str_format)->str:
        return datetime.datetime.strptime(str(year) + "-" + str(day_num), "%Y-%j").strftime(str_format)
# Out:
# Overwriting VietNamDateTimeHandler.py

# %%
# %%writefile AbstractHourlyWeatherCrawler.py
from abc import ABC, abstractmethod
import datetime, calendar
from VietNamDateTimeHandler import VietNamDateTimeHandler
class AbstractHourlyWeatherCrawler(ABC):
    def __init__(self,year):
        self.year=year
        self.APIKey = "e1f10a1e78da46f5b10a1e78da96f525"
        self.base_url = "https://api.weather.com/v1/location/{location}/observations/historical.json?apiKey={apiKey}&units=m&startDate={date}"\
        .format(location="{location}",apiKey=self.APIKey,date="{date}")
        self.year_data={}
        self.date_time_handler = VietNamDateTimeHandler()

    def get_year_data(self)->list:
        location_url = self.get_location_url()
        if not self.year_data:
            self.year_data = []
            n_days = self.date_time_handler.get_num_days_of_year(self.year)
            for i in range(1,n_days+1):
                # str_date = self.get_date_from_day_num(i,"%Y%m%d")
                # str_key_date = self.get_date_from_day_num(i,"%Y-%m-%d")
                self.year_data.extend(self.get_hourly_data(location_url,i))
        return self.year_data

    @abstractmethod
    def get_location_url(self)->str:
        pass

    @abstractmethod
    def get_hourly_data(self,location_url,day)->list:
        pass
# Out:
# Overwriting AbstractHourlyWeatherCrawler.py

# %%
# %%writefile NoiBaiHourlyWeatherCrawler.py
from AbstractHourlyWeatherCrawler import AbstractHourlyWeatherCrawler
from bs4 import BeautifulSoup
import requests
import json
class NoiBaiHourlyWeatherCrawler(AbstractHourlyWeatherCrawler):

    def __init__(self,year):
        super().__init__(year)
        self.time_range=self.get_time_observation_range()

    def get_time_observation_range(self)->list:
        time_range=[]
        mins = ["00","30"]
        for i in range(24):
            for min in mins:
                time_range.append(f"{i:02d}:{min:s}:00")
        return time_range

    def index_time(self,day,time_range)->dict:
        time_idx ={}
        for idx, _time in enumerate(time_range):
            time_idx[f"{day:s} {_time:s}"]=idx
        return time_idx
     
    def get_location_url(self)->str:
        return self.base_url.format(location="VVNB:9:VN",date="{date}")

    def init_observation(self,time_idx):
        len_observation = len(time_idx)
        observation = [{"time":None, "temp":None,"humidity":None} for i in range(len_observation)]
        for _time, idx in time_idx.items():
            observation[idx]["time"] = _time
        return observation
    
    def get_hourly_data(self,location_url,day_num)->list:
        str_key_date = self.date_time_handler.get_date_from_day_num(self.year,day_num,"%Y-%m-%d")
        
        api_day = self.date_time_handler.get_date_from_day_num(self.year,day_num,"%Y%m%d")
        api_url = location_url.format(date=api_day)
        web = requests.get(api_url)
        soup = BeautifulSoup(web.content, "html.parser")
        json_soup = json.loads(soup.get_text())

        time_idx = self.index_time(str_key_date,self.time_range)
        observations=self.init_observation(time_idx)
        try :
            for ele in json_soup["observations"]:
                date_time = self.date_time_handler.convert_timestampe(ele["valid_time_gmt"])
                try :
                    observations[time_idx[date_time]]["temp"] = ele["temp"]
                    observations[time_idx[date_time]]["humidity"] = ele["rh"]
                except:
                    print(f"DateTime {date_time:s} is out of scope")
        except :
            print(f"Observations Error in day: {str_key_date:s}")
        return observations
# Out:
# Overwriting NoiBaiHourlyWeatherCrawler.py

# %%
# %%writefile main.py
from NoiBaiHourlyWeatherCrawler import NoiBaiHourlyWeatherCrawler
import pandas as pd
import argparse

def save_to_file(weather_data:list,filename:str):
    _filename = f"data/{filename:s}"
    df = pd.DataFrame.from_dict(weather_data)
    df.to_csv(_filename,mode="a",header=False)


if __name__=="__main__":
    # create parser
    print("Parsing Args")
    parser = argparse.ArgumentParser()
    parser.add_argument("year")
    parser.add_argument("filename")
    args = parser.parse_args()
 
    print("Start crawling weather data in {year}".format(year=args.year))
    year = int(args.year)
    crawler = NoiBaiHourlyWeatherCrawler(year) 
    weather_data = crawler.get_year_data()
    print("Done Crawling.\nStart Saving ",args.filename)
    save_to_file(weather_data,args.filename)
    print("Done Saving")
# Out:
# Overwriting main.py

# %%
# !mkdir data
# !python3 main.py 2005 weather2005.csv
# with open("data/weather.csv","w") as f:
#     f.writelines("time,temp,humidity\n")

# %%
with open("data/weather.csv","w") as f:
    f.writelines("time,temperature,humidity\n")

# %%
# %%bash
# for i in {2007..2021}
# do
#    python3 main.py $i weather0721.csv
# done
# Out:
# Parsing Args
# Start crawling weather data in 2007
# DateTime 2007-01-08 15:10:00 is out of scope
# DateTime 2007-01-24 16:29:00 is out of scope
# DateTime 2007-02-14 09:21:00 is out of scope
# DateTime 2007-02-21 14:01:00 is out of scope
# DateTime 2007-02-21 15:40:00 is out of scope
# DateTime 2007-02-21 16:09:00 is out of scope
# DateTime 2007-02-28 13:12:00 is out of scope
# DateTime 2007-06-10 23:59:00 is out of scope
# DateTime 2007-07-14 15:31:00 is out of scope
# DateTime 2007-08-05 03:14:00 is out of scope
# DateTime 2007-08-07 14:00:00 is out of scope
# DateTime 2007-10-01 17:59:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2008
# DateTime 2008-02-04 14:02:00 is out of scope
# DateTime 2008-03-30 08:05:00 is out of scope
# DateTime 2008-07-17 20:50:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2009
# DateTime 2009-03-05 13:17:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2010
# DateTime 2010-01-25 12:30:00 is out of scope
# DateTime 2010-04-14 01:31:00 is out of scope
# DateTime 2010-05-06 05:05:00 is out of scope
# DateTime 2010-05-10 08:15:00 is out of scope
# DateTime 2010-08-26 03:05:00 is out of scope
# DateTime 2010-10-08 14:05:00 is out of scope
# DateTime 2010-11-24 12:30:00 is out of scope
# DateTime 2010-11-26 13:30:00 is out of scope
# DateTime 2010-12-05 13:30:00 is out of scope
# DateTime 2010-12-16 12:30:00 is out of scope
# DateTime 2010-12-16 13:00:00 is out of scope
# DateTime 2010-12-18 12:30:00 is out of scope
# DateTime 2010-12-20 12:30:00 is out of scope
# DateTime 2010-12-21 12:30:00 is out of scope
# DateTime 2010-12-22 12:30:00 is out of scope
# DateTime 2010-12-27 12:30:00 is out of scope
# DateTime 2010-12-27 13:00:00 is out of scope
# DateTime 2010-12-27 13:30:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2011
# DateTime 2011-01-09 12:30:00 is out of scope
# DateTime 2011-01-18 12:30:00 is out of scope
# DateTime 2011-01-18 13:00:00 is out of scope
# DateTime 2011-01-25 12:30:00 is out of scope
# DateTime 2011-01-26 12:30:00 is out of scope
# DateTime 2011-01-26 13:00:00 is out of scope
# DateTime 2011-01-26 13:30:00 is out of scope
# DateTime 2011-01-27 12:30:00 is out of scope
# DateTime 2011-01-27 13:30:00 is out of scope
# DateTime 2011-01-28 12:30:00 is out of scope
# DateTime 2011-01-28 13:00:00 is out of scope
# DateTime 2011-01-28 13:30:00 is out of scope
# DateTime 2011-01-29 12:30:00 is out of scope
# DateTime 2011-01-30 12:30:00 is out of scope
# DateTime 2011-02-01 12:30:00 is out of scope
# DateTime 2011-06-27 13:31:00 is out of scope
# DateTime 2011-08-03 09:31:00 is out of scope
# DateTime 2011-08-11 04:05:00 is out of scope
# DateTime 2011-09-04 02:02:00 is out of scope
# DateTime 2011-10-19 16:31:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2012
# DateTime 2012-04-27 17:29:00 is out of scope
# DateTime 2012-07-20 10:08:00 is out of scope
# DateTime 2012-09-13 09:04:00 is out of scope
# DateTime 2012-10-24 04:27:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2013
# DateTime 2013-01-27 20:37:00 is out of scope
# DateTime 2013-03-30 22:13:00 is out of scope
# DateTime 2013-05-06 15:32:00 is out of scope
# DateTime 2013-07-23 12:41:00 is out of scope
# DateTime 2013-07-30 07:03:00 is out of scope
# Observations Error in day: 2013-10-02
# Observations Error in day: 2013-10-03
# Observations Error in day: 2013-10-04
# Observations Error in day: 2013-10-05
# Observations Error in day: 2013-10-06
# DateTime 2013-11-20 10:07:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2014
# DateTime 2014-02-21 14:59:00 is out of scope
# DateTime 2014-04-25 14:56:00 is out of scope
# DateTime 2014-04-26 20:33:00 is out of scope
# DateTime 2014-06-22 08:39:00 is out of scope
# DateTime 2014-08-05 18:41:00 is out of scope
# DateTime 2014-09-18 14:01:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2015
# DateTime 2015-04-07 09:04:00 is out of scope
# DateTime 2015-07-04 23:12:00 is out of scope
# Observations Error in day: 2015-10-31
# Observations Error in day: 2015-11-01
# Observations Error in day: 2015-11-02
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2016
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2017
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2018
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2019
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2020
# DateTime 2020-02-05 04:01:00 is out of scope
# DateTime 2020-05-01 07:01:00 is out of scope
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving
# Parsing Args
# Start crawling weather data in 2021
# Done Crawling.
# Start Saving  weather0721.csv
# Done Saving

# %%
# %cd /content/drive/MyDrive/AI/TemperatureForecast/
# !ls data
import pandas as pd
df = pd.read_csv("data/temp_weather0721.csv")
df.head(10)
# Out:
# /content/drive/MyDrive/AI/TemperatureForecast
# temp_weather1721.csv  weather0721.csv  weather.csv
#    Unnamed: 0                 time  temp  humidity
# 0           0  2007-01-01 00:00:00  18.0      88.0
# 1           1  2007-01-01 00:30:00  18.0      83.0
# 2           2  2007-01-01 01:00:00  18.0      88.0
# 3           3  2007-01-01 01:30:00  18.0      88.0
# 4           4  2007-01-01 02:00:00  18.0      88.0
# 5           5  2007-01-01 02:30:00  18.0      88.0
# 6           6  2007-01-01 03:00:00  18.0      88.0
# 7           7  2007-01-01 03:30:00  18.0      88.0
# 8           8  2007-01-01 04:00:00  18.0      83.0
# 9           9  2007-01-01 04:30:00  18.0      83.0

# %%
import numpy as np
copied_day = "2015-10-29 "
days= ["2015-10-30 ","2015-10-31 ","2015-11-01 ","2015-11-02 "]
time_range=[]
mins = ["00","30"]
for i in range(24):
    for min in mins :
        time_range.append(f"{i:02d}:{min:s}:00")

for tr in time_range:
    for day in days:
        time_to_fill = day+tr
        time_for_fill = copied_day+tr
        print(f"Copying {time_for_fill:s} to {time_to_fill:s}")
        idx = np.flatnonzero(df["time"]==time_to_fill)[0]
        idx2= np.flatnonzero(df["time"]==time_for_fill)[0]
        temp = df.iloc[idx2]["temp"]
        humidity = df.iloc[idx2]["humidity"]
        print(f"At {time_for_fill:s}: temp = {temp:f}, hum = {humidity:f}")
        df.loc[df.time==time_to_fill,"temp"]=temp
        df.loc[df.time==time_to_fill,"humidity"]=humidity
        print(f"Check after copy. Time {time_to_fill:s}: ",end="")
        print(df.loc[df.time==time_to_fill,"temp"])

print("===============================================")
print("After filled")
print(df.loc[df["time"]=="2015-10-29 17:30:00"]["temp"])
print(df.loc[df["time"]=="2015-10-30 17:30:00"]["temp"])
print(df.loc[df["time"]=="2015-11-01 17:30:00"]["temp"])
print(df.loc[df["time"]=="2015-11-02 17:30:00"]["temp"])
# Out:
# Copying 2015-10-29 00:00:00 to 2015-10-30 00:00:00
# At 2015-10-29 00:00:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-10-30 00:00:00: 14496    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:00:00 to 2015-10-31 00:00:00
# At 2015-10-29 00:00:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-10-31 00:00:00: 14544    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:00:00 to 2015-11-01 00:00:00
# At 2015-10-29 00:00:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-11-01 00:00:00: 14592    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:00:00 to 2015-11-02 00:00:00
# At 2015-10-29 00:00:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-11-02 00:00:00: 14640    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:30:00 to 2015-10-30 00:30:00
# At 2015-10-29 00:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-10-30 00:30:00: 14497    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:30:00 to 2015-10-31 00:30:00
# At 2015-10-29 00:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-10-31 00:30:00: 14545    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:30:00 to 2015-11-01 00:30:00
# At 2015-10-29 00:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-11-01 00:30:00: 14593    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 00:30:00 to 2015-11-02 00:30:00
# At 2015-10-29 00:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-11-02 00:30:00: 14641    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:00:00 to 2015-10-30 01:00:00
# At 2015-10-29 01:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 01:00:00: 14498    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:00:00 to 2015-10-31 01:00:00
# At 2015-10-29 01:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 01:00:00: 14546    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:00:00 to 2015-11-01 01:00:00
# At 2015-10-29 01:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 01:00:00: 14594    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:00:00 to 2015-11-02 01:00:00
# At 2015-10-29 01:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 01:00:00: 14642    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:30:00 to 2015-10-30 01:30:00
# At 2015-10-29 01:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 01:30:00: 14499    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:30:00 to 2015-10-31 01:30:00
# At 2015-10-29 01:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 01:30:00: 14547    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:30:00 to 2015-11-01 01:30:00
# At 2015-10-29 01:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 01:30:00: 14595    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 01:30:00 to 2015-11-02 01:30:00
# At 2015-10-29 01:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 01:30:00: 14643    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:00:00 to 2015-10-30 02:00:00
# At 2015-10-29 02:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 02:00:00: 14500    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:00:00 to 2015-10-31 02:00:00
# At 2015-10-29 02:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 02:00:00: 14548    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:00:00 to 2015-11-01 02:00:00
# At 2015-10-29 02:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 02:00:00: 14596    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:00:00 to 2015-11-02 02:00:00
# At 2015-10-29 02:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 02:00:00: 14644    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:30:00 to 2015-10-30 02:30:00
# At 2015-10-29 02:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 02:30:00: 14501    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:30:00 to 2015-10-31 02:30:00
# At 2015-10-29 02:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 02:30:00: 14549    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:30:00 to 2015-11-01 02:30:00
# At 2015-10-29 02:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 02:30:00: 14597    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 02:30:00 to 2015-11-02 02:30:00
# At 2015-10-29 02:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 02:30:00: 14645    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:00:00 to 2015-10-30 03:00:00
# At 2015-10-29 03:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 03:00:00: 14502    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:00:00 to 2015-10-31 03:00:00
# At 2015-10-29 03:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 03:00:00: 14550    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:00:00 to 2015-11-01 03:00:00
# At 2015-10-29 03:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 03:00:00: 14598    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:00:00 to 2015-11-02 03:00:00
# At 2015-10-29 03:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 03:00:00: 14646    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:30:00 to 2015-10-30 03:30:00
# At 2015-10-29 03:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 03:30:00: 14503    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:30:00 to 2015-10-31 03:30:00
# At 2015-10-29 03:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 03:30:00: 14551    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:30:00 to 2015-11-01 03:30:00
# At 2015-10-29 03:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 03:30:00: 14599    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 03:30:00 to 2015-11-02 03:30:00
# At 2015-10-29 03:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 03:30:00: 14647    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:00:00 to 2015-10-30 04:00:00
# At 2015-10-29 04:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 04:00:00: 14504    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:00:00 to 2015-10-31 04:00:00
# At 2015-10-29 04:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 04:00:00: 14552    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:00:00 to 2015-11-01 04:00:00
# At 2015-10-29 04:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 04:00:00: 14600    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:00:00 to 2015-11-02 04:00:00
# At 2015-10-29 04:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 04:00:00: 14648    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:30:00 to 2015-10-30 04:30:00
# At 2015-10-29 04:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 04:30:00: 14505    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:30:00 to 2015-10-31 04:30:00
# At 2015-10-29 04:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 04:30:00: 14553    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:30:00 to 2015-11-01 04:30:00
# At 2015-10-29 04:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 04:30:00: 14601    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 04:30:00 to 2015-11-02 04:30:00
# At 2015-10-29 04:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 04:30:00: 14649    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:00:00 to 2015-10-30 05:00:00
# At 2015-10-29 05:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 05:00:00: 14506    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:00:00 to 2015-10-31 05:00:00
# At 2015-10-29 05:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 05:00:00: 14554    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:00:00 to 2015-11-01 05:00:00
# At 2015-10-29 05:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 05:00:00: 14602    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:00:00 to 2015-11-02 05:00:00
# At 2015-10-29 05:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 05:00:00: 14650    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:30:00 to 2015-10-30 05:30:00
# At 2015-10-29 05:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 05:30:00: 14507    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:30:00 to 2015-10-31 05:30:00
# At 2015-10-29 05:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 05:30:00: 14555    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:30:00 to 2015-11-01 05:30:00
# At 2015-10-29 05:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 05:30:00: 14603    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 05:30:00 to 2015-11-02 05:30:00
# At 2015-10-29 05:30:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 05:30:00: 14651    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:00:00 to 2015-10-30 06:00:00
# At 2015-10-29 06:00:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-10-30 06:00:00: 14508    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:00:00 to 2015-10-31 06:00:00
# At 2015-10-29 06:00:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-10-31 06:00:00: 14556    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:00:00 to 2015-11-01 06:00:00
# At 2015-10-29 06:00:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-11-01 06:00:00: 14604    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:00:00 to 2015-11-02 06:00:00
# At 2015-10-29 06:00:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-11-02 06:00:00: 14652    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:30:00 to 2015-10-30 06:30:00
# At 2015-10-29 06:30:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-10-30 06:30:00: 14509    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:30:00 to 2015-10-31 06:30:00
# At 2015-10-29 06:30:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-10-31 06:30:00: 14557    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:30:00 to 2015-11-01 06:30:00
# At 2015-10-29 06:30:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-11-01 06:30:00: 14605    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 06:30:00 to 2015-11-02 06:30:00
# At 2015-10-29 06:30:00: temp = 25.000000, hum = 83.000000
# Check after copy. Time 2015-11-02 06:30:00: 14653    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:00:00 to 2015-10-30 07:00:00
# At 2015-10-29 07:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-30 07:00:00: 14510    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:00:00 to 2015-10-31 07:00:00
# At 2015-10-29 07:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-10-31 07:00:00: 14558    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:00:00 to 2015-11-01 07:00:00
# At 2015-10-29 07:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-01 07:00:00: 14606    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:00:00 to 2015-11-02 07:00:00
# At 2015-10-29 07:00:00: temp = 25.000000, hum = 89.000000
# Check after copy. Time 2015-11-02 07:00:00: 14654    25.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:30:00 to 2015-10-30 07:30:00
# At 2015-10-29 07:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-10-30 07:30:00: 14511    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:30:00 to 2015-10-31 07:30:00
# At 2015-10-29 07:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-10-31 07:30:00: 14559    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:30:00 to 2015-11-01 07:30:00
# At 2015-10-29 07:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-11-01 07:30:00: 14607    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 07:30:00 to 2015-11-02 07:30:00
# At 2015-10-29 07:30:00: temp = 26.000000, hum = 83.000000
# Check after copy. Time 2015-11-02 07:30:00: 14655    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:00:00 to 2015-10-30 08:00:00
# At 2015-10-29 08:00:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-10-30 08:00:00: 14512    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:00:00 to 2015-10-31 08:00:00
# At 2015-10-29 08:00:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-10-31 08:00:00: 14560    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:00:00 to 2015-11-01 08:00:00
# At 2015-10-29 08:00:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-11-01 08:00:00: 14608    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:00:00 to 2015-11-02 08:00:00
# At 2015-10-29 08:00:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-11-02 08:00:00: 14656    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:30:00 to 2015-10-30 08:30:00
# At 2015-10-29 08:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-10-30 08:30:00: 14513    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:30:00 to 2015-10-31 08:30:00
# At 2015-10-29 08:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-10-31 08:30:00: 14561    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:30:00 to 2015-11-01 08:30:00
# At 2015-10-29 08:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-11-01 08:30:00: 14609    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 08:30:00 to 2015-11-02 08:30:00
# At 2015-10-29 08:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-11-02 08:30:00: 14657    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:00:00 to 2015-10-30 09:00:00
# At 2015-10-29 09:00:00: temp = 29.000000, hum = 74.000000
# Check after copy. Time 2015-10-30 09:00:00: 14514    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:00:00 to 2015-10-31 09:00:00
# At 2015-10-29 09:00:00: temp = 29.000000, hum = 74.000000
# Check after copy. Time 2015-10-31 09:00:00: 14562    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:00:00 to 2015-11-01 09:00:00
# At 2015-10-29 09:00:00: temp = 29.000000, hum = 74.000000
# Check after copy. Time 2015-11-01 09:00:00: 14610    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:00:00 to 2015-11-02 09:00:00
# At 2015-10-29 09:00:00: temp = 29.000000, hum = 74.000000
# Check after copy. Time 2015-11-02 09:00:00: 14658    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:30:00 to 2015-10-30 09:30:00
# At 2015-10-29 09:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-30 09:30:00: 14515    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:30:00 to 2015-10-31 09:30:00
# At 2015-10-29 09:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-31 09:30:00: 14563    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:30:00 to 2015-11-01 09:30:00
# At 2015-10-29 09:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-01 09:30:00: 14611    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 09:30:00 to 2015-11-02 09:30:00
# At 2015-10-29 09:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-02 09:30:00: 14659    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:00:00 to 2015-10-30 10:00:00
# At 2015-10-29 10:00:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-30 10:00:00: 14516    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:00:00 to 2015-10-31 10:00:00
# At 2015-10-29 10:00:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-31 10:00:00: 14564    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:00:00 to 2015-11-01 10:00:00
# At 2015-10-29 10:00:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-01 10:00:00: 14612    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:00:00 to 2015-11-02 10:00:00
# At 2015-10-29 10:00:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-02 10:00:00: 14660    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:30:00 to 2015-10-30 10:30:00
# At 2015-10-29 10:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-30 10:30:00: 14517    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:30:00 to 2015-10-31 10:30:00
# At 2015-10-29 10:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-31 10:30:00: 14565    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:30:00 to 2015-11-01 10:30:00
# At 2015-10-29 10:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-01 10:30:00: 14613    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 10:30:00 to 2015-11-02 10:30:00
# At 2015-10-29 10:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-02 10:30:00: 14661    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:00:00 to 2015-10-30 11:00:00
# At 2015-10-29 11:00:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-10-30 11:00:00: 14518    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:00:00 to 2015-10-31 11:00:00
# At 2015-10-29 11:00:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-10-31 11:00:00: 14566    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:00:00 to 2015-11-01 11:00:00
# At 2015-10-29 11:00:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-11-01 11:00:00: 14614    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:00:00 to 2015-11-02 11:00:00
# At 2015-10-29 11:00:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-11-02 11:00:00: 14662    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:30:00 to 2015-10-30 11:30:00
# At 2015-10-29 11:30:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-10-30 11:30:00: 14519    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:30:00 to 2015-10-31 11:30:00
# At 2015-10-29 11:30:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-10-31 11:30:00: 14567    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:30:00 to 2015-11-01 11:30:00
# At 2015-10-29 11:30:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-11-01 11:30:00: 14615    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 11:30:00 to 2015-11-02 11:30:00
# At 2015-10-29 11:30:00: temp = 31.000000, hum = 55.000000
# Check after copy. Time 2015-11-02 11:30:00: 14663    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:00:00 to 2015-10-30 12:00:00
# At 2015-10-29 12:00:00: temp = 32.000000, hum = 52.000000
# Check after copy. Time 2015-10-30 12:00:00: 14520    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:00:00 to 2015-10-31 12:00:00
# At 2015-10-29 12:00:00: temp = 32.000000, hum = 52.000000
# Check after copy. Time 2015-10-31 12:00:00: 14568    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:00:00 to 2015-11-01 12:00:00
# At 2015-10-29 12:00:00: temp = 32.000000, hum = 52.000000
# Check after copy. Time 2015-11-01 12:00:00: 14616    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:00:00 to 2015-11-02 12:00:00
# At 2015-10-29 12:00:00: temp = 32.000000, hum = 52.000000
# Check after copy. Time 2015-11-02 12:00:00: 14664    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:30:00 to 2015-10-30 12:30:00
# At 2015-10-29 12:30:00: temp = 33.000000, hum = 46.000000
# Check after copy. Time 2015-10-30 12:30:00: 14521    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:30:00 to 2015-10-31 12:30:00
# At 2015-10-29 12:30:00: temp = 33.000000, hum = 46.000000
# Check after copy. Time 2015-10-31 12:30:00: 14569    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:30:00 to 2015-11-01 12:30:00
# At 2015-10-29 12:30:00: temp = 33.000000, hum = 46.000000
# Check after copy. Time 2015-11-01 12:30:00: 14617    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 12:30:00 to 2015-11-02 12:30:00
# At 2015-10-29 12:30:00: temp = 33.000000, hum = 46.000000
# Check after copy. Time 2015-11-02 12:30:00: 14665    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:00:00 to 2015-10-30 13:00:00
# At 2015-10-29 13:00:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-10-30 13:00:00: 14522    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:00:00 to 2015-10-31 13:00:00
# At 2015-10-29 13:00:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-10-31 13:00:00: 14570    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:00:00 to 2015-11-01 13:00:00
# At 2015-10-29 13:00:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-11-01 13:00:00: 14618    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:00:00 to 2015-11-02 13:00:00
# At 2015-10-29 13:00:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-11-02 13:00:00: 14666    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:30:00 to 2015-10-30 13:30:00
# At 2015-10-29 13:30:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-10-30 13:30:00: 14523    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:30:00 to 2015-10-31 13:30:00
# At 2015-10-29 13:30:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-10-31 13:30:00: 14571    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:30:00 to 2015-11-01 13:30:00
# At 2015-10-29 13:30:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-11-01 13:30:00: 14619    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 13:30:00 to 2015-11-02 13:30:00
# At 2015-10-29 13:30:00: temp = 33.000000, hum = 49.000000
# Check after copy. Time 2015-11-02 13:30:00: 14667    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:00:00 to 2015-10-30 14:00:00
# At 2015-10-29 14:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-30 14:00:00: 14524    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:00:00 to 2015-10-31 14:00:00
# At 2015-10-29 14:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-31 14:00:00: 14572    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:00:00 to 2015-11-01 14:00:00
# At 2015-10-29 14:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-01 14:00:00: 14620    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:00:00 to 2015-11-02 14:00:00
# At 2015-10-29 14:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-02 14:00:00: 14668    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:30:00 to 2015-10-30 14:30:00
# At 2015-10-29 14:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-30 14:30:00: 14525    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:30:00 to 2015-10-31 14:30:00
# At 2015-10-29 14:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-31 14:30:00: 14573    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:30:00 to 2015-11-01 14:30:00
# At 2015-10-29 14:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-01 14:30:00: 14621    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 14:30:00 to 2015-11-02 14:30:00
# At 2015-10-29 14:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-02 14:30:00: 14669    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:00:00 to 2015-10-30 15:00:00
# At 2015-10-29 15:00:00: temp = 33.000000, hum = 41.000000
# Check after copy. Time 2015-10-30 15:00:00: 14526    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:00:00 to 2015-10-31 15:00:00
# At 2015-10-29 15:00:00: temp = 33.000000, hum = 41.000000
# Check after copy. Time 2015-10-31 15:00:00: 14574    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:00:00 to 2015-11-01 15:00:00
# At 2015-10-29 15:00:00: temp = 33.000000, hum = 41.000000
# Check after copy. Time 2015-11-01 15:00:00: 14622    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:00:00 to 2015-11-02 15:00:00
# At 2015-10-29 15:00:00: temp = 33.000000, hum = 41.000000
# Check after copy. Time 2015-11-02 15:00:00: 14670    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:30:00 to 2015-10-30 15:30:00
# At 2015-10-29 15:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-30 15:30:00: 14527    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:30:00 to 2015-10-31 15:30:00
# At 2015-10-29 15:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-31 15:30:00: 14575    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:30:00 to 2015-11-01 15:30:00
# At 2015-10-29 15:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-01 15:30:00: 14623    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 15:30:00 to 2015-11-02 15:30:00
# At 2015-10-29 15:30:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-02 15:30:00: 14671    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:00:00 to 2015-10-30 16:00:00
# At 2015-10-29 16:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-30 16:00:00: 14528    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:00:00 to 2015-10-31 16:00:00
# At 2015-10-29 16:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-10-31 16:00:00: 14576    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:00:00 to 2015-11-01 16:00:00
# At 2015-10-29 16:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-01 16:00:00: 14624    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:00:00 to 2015-11-02 16:00:00
# At 2015-10-29 16:00:00: temp = 33.000000, hum = 43.000000
# Check after copy. Time 2015-11-02 16:00:00: 14672    33.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:30:00 to 2015-10-30 16:30:00
# At 2015-10-29 16:30:00: temp = 32.000000, hum = 55.000000
# Check after copy. Time 2015-10-30 16:30:00: 14529    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:30:00 to 2015-10-31 16:30:00
# At 2015-10-29 16:30:00: temp = 32.000000, hum = 55.000000
# Check after copy. Time 2015-10-31 16:30:00: 14577    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:30:00 to 2015-11-01 16:30:00
# At 2015-10-29 16:30:00: temp = 32.000000, hum = 55.000000
# Check after copy. Time 2015-11-01 16:30:00: 14625    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 16:30:00 to 2015-11-02 16:30:00
# At 2015-10-29 16:30:00: temp = 32.000000, hum = 55.000000
# Check after copy. Time 2015-11-02 16:30:00: 14673    32.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:00:00 to 2015-10-30 17:00:00
# At 2015-10-29 17:00:00: temp = 31.000000, hum = 58.000000
# Check after copy. Time 2015-10-30 17:00:00: 14530    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:00:00 to 2015-10-31 17:00:00
# At 2015-10-29 17:00:00: temp = 31.000000, hum = 58.000000
# Check after copy. Time 2015-10-31 17:00:00: 14578    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:00:00 to 2015-11-01 17:00:00
# At 2015-10-29 17:00:00: temp = 31.000000, hum = 58.000000
# Check after copy. Time 2015-11-01 17:00:00: 14626    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:00:00 to 2015-11-02 17:00:00
# At 2015-10-29 17:00:00: temp = 31.000000, hum = 58.000000
# Check after copy. Time 2015-11-02 17:00:00: 14674    31.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:30:00 to 2015-10-30 17:30:00
# At 2015-10-29 17:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-30 17:30:00: 14531    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:30:00 to 2015-10-31 17:30:00
# At 2015-10-29 17:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-10-31 17:30:00: 14579    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:30:00 to 2015-11-01 17:30:00
# At 2015-10-29 17:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-01 17:30:00: 14627    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 17:30:00 to 2015-11-02 17:30:00
# At 2015-10-29 17:30:00: temp = 30.000000, hum = 62.000000
# Check after copy. Time 2015-11-02 17:30:00: 14675    30.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:00:00 to 2015-10-30 18:00:00
# At 2015-10-29 18:00:00: temp = 29.000000, hum = 70.000000
# Check after copy. Time 2015-10-30 18:00:00: 14532    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:00:00 to 2015-10-31 18:00:00
# At 2015-10-29 18:00:00: temp = 29.000000, hum = 70.000000
# Check after copy. Time 2015-10-31 18:00:00: 14580    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:00:00 to 2015-11-01 18:00:00
# At 2015-10-29 18:00:00: temp = 29.000000, hum = 70.000000
# Check after copy. Time 2015-11-01 18:00:00: 14628    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:00:00 to 2015-11-02 18:00:00
# At 2015-10-29 18:00:00: temp = 29.000000, hum = 70.000000
# Check after copy. Time 2015-11-02 18:00:00: 14676    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:30:00 to 2015-10-30 18:30:00
# At 2015-10-29 18:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-10-30 18:30:00: 14533    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:30:00 to 2015-10-31 18:30:00
# At 2015-10-29 18:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-10-31 18:30:00: 14581    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:30:00 to 2015-11-01 18:30:00
# At 2015-10-29 18:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-11-01 18:30:00: 14629    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 18:30:00 to 2015-11-02 18:30:00
# At 2015-10-29 18:30:00: temp = 28.000000, hum = 74.000000
# Check after copy. Time 2015-11-02 18:30:00: 14677    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:00:00 to 2015-10-30 19:00:00
# At 2015-10-29 19:00:00: temp = 28.000000, hum = 70.000000
# Check after copy. Time 2015-10-30 19:00:00: 14534    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:00:00 to 2015-10-31 19:00:00
# At 2015-10-29 19:00:00: temp = 28.000000, hum = 70.000000
# Check after copy. Time 2015-10-31 19:00:00: 14582    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:00:00 to 2015-11-01 19:00:00
# At 2015-10-29 19:00:00: temp = 28.000000, hum = 70.000000
# Check after copy. Time 2015-11-01 19:00:00: 14630    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:00:00 to 2015-11-02 19:00:00
# At 2015-10-29 19:00:00: temp = 28.000000, hum = 70.000000
# Check after copy. Time 2015-11-02 19:00:00: 14678    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:30:00 to 2015-10-30 19:30:00
# At 2015-10-29 19:30:00: temp = 29.000000, hum = 62.000000
# Check after copy. Time 2015-10-30 19:30:00: 14535    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:30:00 to 2015-10-31 19:30:00
# At 2015-10-29 19:30:00: temp = 29.000000, hum = 62.000000
# Check after copy. Time 2015-10-31 19:30:00: 14583    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:30:00 to 2015-11-01 19:30:00
# At 2015-10-29 19:30:00: temp = 29.000000, hum = 62.000000
# Check after copy. Time 2015-11-01 19:30:00: 14631    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 19:30:00 to 2015-11-02 19:30:00
# At 2015-10-29 19:30:00: temp = 29.000000, hum = 62.000000
# Check after copy. Time 2015-11-02 19:30:00: 14679    29.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:00:00 to 2015-10-30 20:00:00
# At 2015-10-29 20:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-10-30 20:00:00: 14536    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:00:00 to 2015-10-31 20:00:00
# At 2015-10-29 20:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-10-31 20:00:00: 14584    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:00:00 to 2015-11-01 20:00:00
# At 2015-10-29 20:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-11-01 20:00:00: 14632    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:00:00 to 2015-11-02 20:00:00
# At 2015-10-29 20:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-11-02 20:00:00: 14680    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:30:00 to 2015-10-30 20:30:00
# At 2015-10-29 20:30:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-10-30 20:30:00: 14537    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:30:00 to 2015-10-31 20:30:00
# At 2015-10-29 20:30:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-10-31 20:30:00: 14585    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:30:00 to 2015-11-01 20:30:00
# At 2015-10-29 20:30:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-11-01 20:30:00: 14633    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 20:30:00 to 2015-11-02 20:30:00
# At 2015-10-29 20:30:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-11-02 20:30:00: 14681    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:00:00 to 2015-10-30 21:00:00
# At 2015-10-29 21:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-10-30 21:00:00: 14538    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:00:00 to 2015-10-31 21:00:00
# At 2015-10-29 21:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-10-31 21:00:00: 14586    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:00:00 to 2015-11-01 21:00:00
# At 2015-10-29 21:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-11-01 21:00:00: 14634    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:00:00 to 2015-11-02 21:00:00
# At 2015-10-29 21:00:00: temp = 28.000000, hum = 66.000000
# Check after copy. Time 2015-11-02 21:00:00: 14682    28.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:30:00 to 2015-10-30 21:30:00
# At 2015-10-29 21:30:00: temp = 27.000000, hum = 70.000000
# Check after copy. Time 2015-10-30 21:30:00: 14539    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:30:00 to 2015-10-31 21:30:00
# At 2015-10-29 21:30:00: temp = 27.000000, hum = 70.000000
# Check after copy. Time 2015-10-31 21:30:00: 14587    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:30:00 to 2015-11-01 21:30:00
# At 2015-10-29 21:30:00: temp = 27.000000, hum = 70.000000
# Check after copy. Time 2015-11-01 21:30:00: 14635    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 21:30:00 to 2015-11-02 21:30:00
# At 2015-10-29 21:30:00: temp = 27.000000, hum = 70.000000
# Check after copy. Time 2015-11-02 21:30:00: 14683    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:00:00 to 2015-10-30 22:00:00
# At 2015-10-29 22:00:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-10-30 22:00:00: 14540    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:00:00 to 2015-10-31 22:00:00
# At 2015-10-29 22:00:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-10-31 22:00:00: 14588    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:00:00 to 2015-11-01 22:00:00
# At 2015-10-29 22:00:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-11-01 22:00:00: 14636    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:00:00 to 2015-11-02 22:00:00
# At 2015-10-29 22:00:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-11-02 22:00:00: 14684    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:30:00 to 2015-10-30 22:30:00
# At 2015-10-29 22:30:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-10-30 22:30:00: 14541    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:30:00 to 2015-10-31 22:30:00
# At 2015-10-29 22:30:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-10-31 22:30:00: 14589    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:30:00 to 2015-11-01 22:30:00
# At 2015-10-29 22:30:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-11-01 22:30:00: 14637    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 22:30:00 to 2015-11-02 22:30:00
# At 2015-10-29 22:30:00: temp = 27.000000, hum = 74.000000
# Check after copy. Time 2015-11-02 22:30:00: 14685    27.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:00:00 to 2015-10-30 23:00:00
# At 2015-10-29 23:00:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-10-30 23:00:00: 14542    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:00:00 to 2015-10-31 23:00:00
# At 2015-10-29 23:00:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-10-31 23:00:00: 14590    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:00:00 to 2015-11-01 23:00:00
# At 2015-10-29 23:00:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-11-01 23:00:00: 14638    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:00:00 to 2015-11-02 23:00:00
# At 2015-10-29 23:00:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-11-02 23:00:00: 14686    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:30:00 to 2015-10-30 23:30:00
# At 2015-10-29 23:30:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-10-30 23:30:00: 14543    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:30:00 to 2015-10-31 23:30:00
# At 2015-10-29 23:30:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-10-31 23:30:00: 14591    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:30:00 to 2015-11-01 23:30:00
# At 2015-10-29 23:30:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-11-01 23:30:00: 14639    26.0
# Name: temp, dtype: float64
# Copying 2015-10-29 23:30:00 to 2015-11-02 23:30:00
# At 2015-10-29 23:30:00: temp = 26.000000, hum = 78.000000
# Check after copy. Time 2015-11-02 23:30:00: 14687    26.0
# Name: temp, dtype: float64

# %%
df.count()
# Out:
# Unnamed: 0    262992
# time          262992
# temp          259881
# humidity      258941
# dtype: int64

# %%
df = df.fillna(method='ffill')

# temperature at "2008-02-10 10:00:00" was high unusually, so we replace it by temperature in the previous hour
df.loc[df.time=="2008-02-10 10:00:00","temp"]=11

# %%
df["temperature"].isnull().values.any()
why_nan = df[df.isna().any(axis=1)]
print(why_nan.count())
why_nan.head(10)

# %%
df.to_csv("data/filled_weather0721.csv")
